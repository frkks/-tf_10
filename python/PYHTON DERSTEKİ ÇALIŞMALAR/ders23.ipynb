# %%
with open("istiklal.txt", "r", encoding = "utf-8") as file :
    lines = file.readlines()

# %%
lines
# Out:
# ['Korkma, sönmez bu şafaklarda yüzen al sancak;\n',
#  'Sönmeden yurdumun üstünde tüten en son ocak.\n',
#  'O benim milletimin yıldızıdır, parlayacak;\n',
#  'O benimdir, o benim milletimindir ancak.\n',
#  '\n',
#  'Çatma, kurban olayım, çehreni ey nazlı hilal!\n',
#  'Kahraman ırkıma bir gül! Ne bu şiddet, bu celal?\n',
#  'Sana olmaz dökülen kanlarımız sonra helal...\n',
#  "Hakkıdır, hakk'a tapan, milletimin istiklal!\n",
#  '\n',
#  'Ben ezelden beridir hür yaşadım, hür yaşarım.\n',
#  'Hangi çılgın bana zincir vuracakmış? Şaşarım!\n',
#  'Kükremiş sel gibiyim, bendimi çiğner, aşarım.\n',
#  'Yırtarım dağları, enginlere sığmam, taşarım.\n',
#  '\n',
#  'Garbın afakını sarmışsa çelik zırhlı duvar,\n',
#  'Benim iman dolu göğsüm gibi serhaddim var.\n',
#  'Ulusun, korkma! Nasıl böyle bir imanı boğar,\n',
#  "'Medeniyet!' dediğin tek dişi kalmış canavar?\n",
#  '\n',
#  'Arkadaş! Yurduma alçakları uğratma, sakın.\n',
#  'Siper et gövdeni, dursun bu hayasızca akın.\n',
# ...

# %%
with open("istiklal.txt", "a", encoding="utf-8") as f :
    for i in lines :
        if i == "\n" :
            pass
        else :
            f.write(i)
            
with open("istiklal.txt", "r", encoding="utf-8") as f :
    print("\n", f.read())
# Out:
#  Korkma, sönmez bu şafaklarda yüzen al sancak;
# Sönmeden yurdumun üstünde tüten en son ocak.
# O benim milletimin yıldızıdır, parlayacak;
# O benimdir, o benim milletimindir ancak.
#
# Çatma, kurban olayım, çehreni ey nazlı hilal!
# Kahraman ırkıma bir gül! Ne bu şiddet, bu celal?
# Sana olmaz dökülen kanlarımız sonra helal...
# Hakkıdır, hakk'a tapan, milletimin istiklal!
#
# Ben ezelden beridir hür yaşadım, hür yaşarım.
# Hangi çılgın bana zincir vuracakmış? Şaşarım!
# Kükremiş sel gibiyim, bendimi çiğner, aşarım.
# Yırtarım dağları, enginlere sığmam, taşarım.
#
# Garbın afakını sarmışsa çelik zırhlı duvar,
# Benim iman dolu göğsüm gibi serhaddim var.
# Ulusun, korkma! Nasıl böyle bir imanı boğar,
# 'Medeniyet!' dediğin tek dişi kalmış canavar?
#
# Arkadaş! Yurduma alçakları uğratma, sakın.
# Siper et gövdeni, dursun bu hayasızca akın.
# Doğacaktır sana va'dettigi günler hakk'ın...
# Kim bilir, belki yarın, belki yarından da yakın.
#
# ...

# %%
with open("fruits.csv", "r", encoding = "utf-8") as ff :
    print(ff.read())
# Out:
# no,fruit,amount
# 1,Banana,4 lb
# 2,Orange,5 lb
# 3,Apple,2 lb
# 4,Strawberry,6 lb
# 5,Cherry,3 lb

# %%
with open("people.csv", "r", encoding = "utf-8") as fil :
    print(fil.read())
# Out:
# no,fruit,amount
# 1,Banana,4 lb
# 2,Orange,5 lb
# 3,Apple,2 lb
# 4,Strawberry,6 lb
# 5,Cherry,3 lb

# %%
import csv

# %%
with open("fruits.csv", "r", newline = "", encoding = "utf-8") as file :
    csv_rows = csv.reader(file)
    for row in csv_rows :
        print(row)
# Out:
# ['no', 'fruit', 'amount']
# ['1', 'Banana', '4 lb']
# ['2', 'Orange', '5 lb']
# ['3', 'Apple', '2 lb']
# ['4', 'Strawberry', '6 lb']
# ['5', 'Cherry', '3 lb']

# %%
with open("fruits.csv", "r", newline = "", encoding = "utf-8") as file :
    csv_rows = csv.reader(file, delimiter = ":") # virgül harici bir şey le böyle çıktı verir
    for row in csv_rows :
        print(row)
# Out:
# ['no,fruit,amount']
# ['1,Banana,4 lb']
# ['2,Orange,5 lb']
# ['3,Apple,2 lb']
# ['4,Strawberry,6 lb']
# ['5,Cherry,3 lb']

# %%
import pandas as pd

# %%
df = pd.read_csv("titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
bayanlar = df[df["Sex"] == "female"]
bayanlar
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
bayanlar.to_csv("titanic_bayanlar.csv", index = False)

# %%
vefat = df[df["Survived"] == 1]
vefat
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
vefat.to_csv("titanic_vefat.csv", index = False)

# %%
df.groupby("Sex")["Survived"].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
df.groupby("Pclass")["Survived"].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
import pandas as plotting

# %%
import pandas as matplotlib

# %%
import importlib

# %%
df.plot("Pclass")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24840/1320754499.py in <module>
# ----> 1 df.plot("Pclass")
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     890
#     891     def __call__(self, *args, **kwargs):
# --> 892         plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#     893
#     894         x, y, kind, kwargs = self._get_call_args(
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\plotting\_core.py in _get_plot_backend(backend)
#    1812         return _backends[backend]
#    1813
# -> 1814     module = _load_backend(backend)
#    1815     _backends[backend] = module
#    1816     return module
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\plotting\_core.py in _load_backend(backend)
# ...

# %%
import pandas as plotting

# %%
import smtplib

# %%
server = smtplib.SMTP("smtp.gmail.com", 587)
server.starttls()
psswo = "38473847"

server.login("frkks47@gmail.com", psswo)

message = "\n merhaba faruk bu mesaj pythondan atıldı."
server.sendmail("frkks47@gmail.com", "ygmrks47@gmail.com", message)

server.quit()
# Out:
# ---------------------------------------------------------------------------
# SMTPAuthenticationError                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24840/3378149886.py in <module>
#       3 psswo = "38473847"
#       4
# ----> 5 server.login("frkks47@gmail.com", psswo)
#       6
#       7 message = "\n merhaba faruk bu mesaj pythondan atıldı."
#
# ~\AppData\Local\Programs\Python\Python39\lib\smtplib.py in login(self, user, password, initial_response_ok)
#     748
#     749         # We could not login successfully.  Return result of last attempt.
# --> 750         raise last_exception
#     751
#     752     def starttls(self, keyfile=None, certfile=None, context=None):
#
# ~\AppData\Local\Programs\Python\Python39\lib\smtplib.py in login(self, user, password, initial_response_ok)
#     737             method_name = 'auth_' + authmethod.lower().replace('-', '_')
#     738             try:
# --> 739                 (code, resp) = self.auth(
# ...
